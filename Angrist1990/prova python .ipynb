# %%
import pandas as pd 
import numpy as np

# %%
cwhsa = pd.read_stata('cwhsa.dta')
cwhsc_new = pd.read_stata('cwhsc_new.dta')
cwhsb = pd.read_stata('cwhsb.dta')

# %%
cwhsa = pd.DataFrame(cwhsa)
cwhsc_new = pd.DataFrame(cwhsc_new)
cwhsb = pd.DataFrame(cwhsb)


cwhsa
# Out:
#        byr  race  interval         vmn1         vsd1   vnu1  vnms1  vfin1  \
# 0       44     1         1  1691.030029  1480.599976  182.0    0.0  0.170
# 1       44     1         2  1535.430054  1359.020020  187.0    0.0  0.187
# 2       44     1         3  1818.010010  1604.420044  210.0    0.0  0.171
# 3       44     1         4  1636.380005  1626.270020  208.0    0.0  0.231
# 4       44     1         5  1889.800049  1639.609985  207.0    0.0  0.184
# ...    ...   ...       ...          ...          ...    ...    ...    ...
# 20435   53     2        69  3643.739990  4273.600098   53.0    1.5  0.415
# 20436   53     2        70  4127.490234  5623.089844   55.0    0.0  0.473
# 20437   53     2        71  4712.459961  4588.279785   76.0    0.0  0.316
# 20438   53     2        72  4676.939941  5321.140137   85.0    0.0  0.353
# 20439   53     2        73  4651.870117  4989.020020   83.0    1.5  0.241
#
#         ltax  xltax  year  ctr1
# 0      0.060  0.049    64     1
# 1      0.043  0.016    64     1
# 2      0.090  0.052    64     1
# 3      0.077  0.034    64     1
# 4      0.068  0.043    64     1
# ...      ...    ...   ...   ...
# 20435  0.000  0.000    77    14
# 20436  0.036  0.018    77    14
# 20437  0.013  0.013    77    14
# 20438  0.012  0.000    77    14
# 20439  0.036  0.024    77    14
#
# [20440 rows x 12 columns]

# %%
#per mettere assieme i dataset aggiungo una colonna Type =0 al secondo, riordino per avere la stessa sequenza di colonne e concateno  
cwhsa['type'] = pd.Series([0 for x in range(len(cwhsa['byr']))])
data= cwhsa[['byr', 'race', 'interval','vmn1','vsd1','vnu1','vnms1', 'vfin1','year','ctr1','type','ltax','xltax']]
data=pd.concat([data,cwhsb ], ignore_index=True)
data
# Out:
#        byr  race  interval          vmn1          vsd1   vnu1  vnms1  vfin1  \
# 0       44     1         1   1691.030029   1480.599976  182.0    0.0  0.170
# 1       44     1         2   1535.430054   1359.020020  187.0    0.0  0.187
# 2       44     1         3   1818.010010   1604.420044  210.0    0.0  0.171
# 3       44     1         4   1636.380005   1626.270020  208.0    0.0  0.231
# 4       44     1         5   1889.800049   1639.609985  207.0    0.0  0.184
# ...    ...   ...       ...           ...           ...    ...    ...    ...
# 40875   53     2        69   6846.430000   9117.490000   53.0    1.5  0.396
# 40876   53     2        70  11357.890000  14734.470000   55.0    0.0  0.455
# 40877   53     2        71   8695.860000   9613.240000   76.0    0.0  0.368
# 40878   53     2        72  14013.240000  14182.300000   84.0    1.5  0.274
# 40879   53     2        73  10742.710000  18095.780000   83.0    1.5  0.506
#
#        year  ctr1   type   ltax  xltax
# 0        64     1      0  0.060  0.049
# 1        64     1      0  0.043  0.016
# 2        64     1      0  0.090  0.052
# 3        64     1      0  0.077  0.034
# 4        64     1      0  0.068  0.043
# ...     ...   ...    ...    ...    ...
# 40875    84    28  TOTAL  0.000  0.000
# 40876    84    28  TOTAL  0.073  0.000
# 40877    84    28  TOTAL  0.000  0.000
# 40878    84    28  TOTAL  0.071  0.000
# 40879    84    28  TOTAL  0.072  0.000
#
# [40880 rows x 13 columns]

# %%
TAB1 = pd.DataFrame(data)

#rimuovo quelli nati prima del 50 ed estratti prima del 65 

for index, row in TAB1.iterrows(): 
    if row['byr']< 50 or row['year'] <= 65 :
        TAB1.drop(index, inplace=True)
    else : 
        pass
        
TAB1
# Out:
#        byr  race  interval          vmn1          vsd1   vnu1  vnms1  vfin1  \
# 6278    50     1         1    192.910004    423.880005  192.0    0.0  0.604
# 6279    50     1         2    133.850006    315.019989  237.0    0.0  0.705
# 6280    50     1         3    141.309998    294.730011  229.0    0.0  0.668
# 6281    50     1         4    175.919998    405.609985  246.0    0.0  0.646
# 6282    50     1         5    187.820007    518.020020  214.0    0.0  0.617
# ...    ...   ...       ...           ...           ...    ...    ...    ...
# 40875   53     2        69   6846.430000   9117.490000   53.0    1.5  0.396
# 40876   53     2        70  11357.890000  14734.470000   55.0    0.0  0.455
# 40877   53     2        71   8695.860000   9613.240000   76.0    0.0  0.368
# 40878   53     2        72  14013.240000  14182.300000   84.0    1.5  0.274
# 40879   53     2        73  10742.710000  18095.780000   83.0    1.5  0.506
#
#        year  ctr1   type   ltax  xltax
# 6278     66     3      0  0.000    0.0
# 6279     66     3      0  0.000    0.0
# 6280     66     3      0  0.000    0.0
# 6281     66     3      0  0.000    0.0
# 6282     66     3      0  0.000    0.0
# ...     ...   ...    ...    ...    ...
# 40875    84    28  TOTAL  0.000    0.0
# 40876    84    28  TOTAL  0.073    0.0
# 40877    84    28  TOTAL  0.000    0.0
# 40878    84    28  TOTAL  0.071    0.0
# 40879    84    28  TOTAL  0.072    0.0
#
# [15184 rows x 13 columns]

# %%
#creo e compilo la colonna sull'elegibilità 
TAB1['elegible'] = pd.Series([0 for x in range(len(TAB1['byr']))])

TAB1['elegible']=np.where(((TAB1['byr']>= 44) & (TAB1['byr']<= 50) & (TAB1['interval']<=39))|((TAB1['byr']==51)  & (TAB1['interval']<=25))|((TAB1['byr']>= 52) & (TAB1['byr']<= 53) & (TAB1['interval']<=59)), 1, 0)
TAB1
# Out:
#        byr  race  interval          vmn1          vsd1   vnu1  vnms1  vfin1  \
# 6278    50     1         1    192.910004    423.880005  192.0    0.0  0.604
# 6279    50     1         2    133.850006    315.019989  237.0    0.0  0.705
# 6280    50     1         3    141.309998    294.730011  229.0    0.0  0.668
# 6281    50     1         4    175.919998    405.609985  246.0    0.0  0.646
# 6282    50     1         5    187.820007    518.020020  214.0    0.0  0.617
# ...    ...   ...       ...           ...           ...    ...    ...    ...
# 40875   53     2        69   6846.430000   9117.490000   53.0    1.5  0.396
# 40876   53     2        70  11357.890000  14734.470000   55.0    0.0  0.455
# 40877   53     2        71   8695.860000   9613.240000   76.0    0.0  0.368
# 40878   53     2        72  14013.240000  14182.300000   84.0    1.5  0.274
# 40879   53     2        73  10742.710000  18095.780000   83.0    1.5  0.506
#
#        year  ctr1   type   ltax  xltax  elegible
# 6278     66     3      0  0.000    0.0         1
# 6279     66     3      0  0.000    0.0         1
# 6280     66     3      0  0.000    0.0         1
# 6281     66     3      0  0.000    0.0         1
# 6282     66     3      0  0.000    0.0         1
# ...     ...   ...    ...    ...    ...       ...
# 40875    84    28  TOTAL  0.000    0.0         0
# 40876    84    28  TOTAL  0.073    0.0         0
# 40877    84    28  TOTAL  0.000    0.0         0
# 40878    84    28  TOTAL  0.071    0.0         0
# 40879    84    28  TOTAL  0.072    0.0         0
#
# [15184 rows x 14 columns]

# %%
# aggiungo nella lista le colonne riguardanti le varianze e i dati medi 
TAB1['earn_nz']=TAB1['vmn1']/(1-TAB1['vfin1'])
TAB1['wt_nz']=TAB1['vnu1']*(1-TAB1['vfin1'])
TAB1['WHITE']=np.where(TAB1['race']==1 , 1 , 0 )
TAB1['non WITHE']=np.where(TAB1['race']==2 , 1 , 0 )
TAB1['var']= TAB1['vsd1']*TAB1['vsd1']

TAB1['var_nz']= TAB1['var']*(TAB1['vnu1']/TAB1['wt_nz'])

# %%
TAB1
# Out:
#        byr  race  interval          vmn1          vsd1   vnu1  vnms1  vfin1  \
# 6278    50     1         1    192.910004    423.880005  192.0    0.0  0.604
# 6279    50     1         2    133.850006    315.019989  237.0    0.0  0.705
# 6280    50     1         3    141.309998    294.730011  229.0    0.0  0.668
# 6281    50     1         4    175.919998    405.609985  246.0    0.0  0.646
# 6282    50     1         5    187.820007    518.020020  214.0    0.0  0.617
# ...    ...   ...       ...           ...           ...    ...    ...    ...
# 40875   53     2        69   6846.430000   9117.490000   53.0    1.5  0.396
# 40876   53     2        70  11357.890000  14734.470000   55.0    0.0  0.455
# 40877   53     2        71   8695.860000   9613.240000   76.0    0.0  0.368
# 40878   53     2        72  14013.240000  14182.300000   84.0    1.5  0.274
# 40879   53     2        73  10742.710000  18095.780000   83.0    1.5  0.506
#
#        year  ctr1   type   ltax  xltax  elegible       earn_nz      wt_nz  \
# 6278     66     3      0  0.000    0.0         1    487.146440  76.032005
# 6279     66     3      0  0.000    0.0         1    453.728809  69.915004
# 6280     66     3      0  0.000    0.0         1    425.632501  76.028004
# 6281     66     3      0  0.000    0.0         1    496.949186  87.083993
# 6282     66     3      0  0.000    0.0         1    490.391643  81.962003
# ...     ...   ...    ...    ...    ...       ...           ...        ...
# 40875    84    28  TOTAL  0.000    0.0         0  11335.149526  32.011999
# 40876    84    28  TOTAL  0.073    0.0         0  20840.166779  29.974998
# 40877    84    28  TOTAL  0.000    0.0         0  13759.272816  48.031998
# 40878    84    28  TOTAL  0.071    0.0         0  19301.983179  60.984001
# 40879    84    28  TOTAL  0.072    0.0         0  21746.375742  41.002001
#
#        WHITE  non WITHE           var        var_nz
# 6278       1          0  1.796743e+05  4.537228e+05
# 6279       1          0  9.923759e+04  3.363986e+05
# 6280       1          0  8.686578e+04  2.616439e+05
# 6281       1          0  1.645195e+05  4.647443e+05
# 6282       1          0  2.683447e+05  7.006390e+05
# ...      ...        ...           ...           ...
# 40875      0          1  8.312862e+07  1.376302e+08
# 40876      0          1  2.171046e+08  3.983571e+08
# 40877      0          1  9.241438e+07  1.462253e+08
# 40878      0          1  2.011376e+08  2.770491e+08
# 40879      0          1  3.274573e+08  6.628689e+08
#
# [15184 rows x 20 columns]

# %%
#calcolo i pesi cumulati per gruppo d'appartenenza 
W_g = TAB1.groupby(['race',"byr",'elegible', "year", 'type']).sum().reset_index()

W_g['sumwt'] = W_g['wt_nz']
W_g['wtmult']= 1 / W_g['wt_nz']

W_g = W_g[['race','byr','elegible', 'year', 'type','sumwt','wtmult']]

# %%
W_g
# Out:
#      race  byr  elegible  year   type        sumwt    wtmult
# 0       1   50         0    66      0  3044.124954  0.000329
# 1       1   50         0    67      0  4703.055986  0.000213
# 2       1   50         0    68      0  5793.951972  0.000173
# 3       1   50         0    69      0  6192.922977  0.000161
# 4       1   50         0    70      0  6155.338975  0.000162
# ..    ...  ...       ...   ...    ...          ...       ...
# 411     2   53         1    82  TOTAL  2494.048993  0.000401
# 412     2   53         1    83  TAXAB  2729.089010  0.000366
# 413     2   53         1    83  TOTAL  2575.931016  0.000388
# 414     2   53         1    84  TAXAB  2737.694012  0.000365
# 415     2   53         1    84  TOTAL  2602.904016  0.000384
#
# [416 rows x 7 columns]

# %%
#ristabilisco gli indici e calcolo var_cm e 
W_2 = W_g.merge(TAB1, left_on=['race','byr','elegible', 'year', 'type'], right_on=['race','byr','elegible', 'year', 'type'], how='left')
W_2['var_cm']=W_2['wtmult']*W_2['var_nz']

W_2['type']= np.where(W_2['type']=='TAXAB', 'FICA', 'W')

W_2
# Out:
#        race  byr  elegible  year type        sumwt    wtmult  interval  \
# 0         1   50         0    66    W  3044.124954  0.000329        40
# 1         1   50         0    66    W  3044.124954  0.000329        41
# 2         1   50         0    66    W  3044.124954  0.000329        42
# 3         1   50         0    66    W  3044.124954  0.000329        43
# 4         1   50         0    66    W  3044.124954  0.000329        44
# ...     ...  ...       ...   ...  ...          ...       ...       ...
# 15179     2   53         1    84    W  2602.904016  0.000384        55
# 15180     2   53         1    84    W  2602.904016  0.000384        56
# 15181     2   53         1    84    W  2602.904016  0.000384        57
# 15182     2   53         1    84    W  2602.904016  0.000384        58
# 15183     2   53         1    84    W  2602.904016  0.000384        59
#
#                vmn1          vsd1  ...  ctr1   ltax  xltax       earn_nz  \
# 0        198.210007    336.779999  ...     3  0.000    0.0    448.438958
# 1        161.789993    381.910004  ...     3  0.000    0.0    463.581673
# 2        198.470001    347.049988  ...     3  0.000    0.0    450.045370
# 3        244.589996    409.989990  ...     3  0.000    0.0    548.408088
# 4        214.190002    376.279999  ...     3  0.000    0.0    505.165071
# ...             ...           ...  ...   ...    ...    ...           ...
# 15179   8800.860000  10686.710000  ...    28  0.030    0.0  13837.829379
# 15180   9757.220000  12444.670000  ...    28  0.038    0.0  15221.871305
# 15181   8828.880000  10959.760000  ...    28  0.012    0.0  14309.368285
# 15182  10352.600000  11085.250000  ...    28  0.026    0.0  17168.491300
# 15183  10154.880000  12750.280000  ...    28  0.026    0.0  15966.791519
#
#             wt_nz  WHITE  non WITHE           var        var_nz        var_cm
# 0       95.913994      1          0  1.134208e+05  2.566081e+05     84.296174
# 1       76.081995      1          0  1.458553e+05  4.179234e+05    137.288511
# 2       93.050997      1          0  1.204437e+05  2.731150e+05     89.718709
# 3      107.931995      1          0  1.680918e+05  3.768874e+05    123.808138
# 4       89.040005      1          0  1.415866e+05  3.339307e+05    109.696788
# ...           ...    ...        ...           ...           ...           ...
# 15179   41.976002      0          1  1.142058e+08  1.795688e+08  68987.872837
# 15180   49.998003      0          1  1.548698e+08  2.416066e+08  92821.923663
# 15181   49.976999      0          1  1.201163e+08  1.946780e+08  74792.626019
# 15182   47.033999      0          1  1.228828e+08  2.037857e+08  78291.664986
# 15183   48.972003      0          1  1.625696e+08  2.556126e+08  98202.863092
#
# [15184 rows x 23 columns]

# %%
#calcolo la media dei parametri per gruppo d'appartenenza, e mantengo solo le colonne di mio interesse  
TAB2 = W_2.groupby(['race',"byr", "year", 'type','elegible']).mean().reset_index()

TAB2 = TAB2[['race','byr', 'year', 'type','elegible', 'var_cm','earn_nz']]

# %%
TAB2
# Out:
#      race  byr  year  type  elegible         var_cm       earn_nz
# 0       1   50    66     W         0     113.333278    473.478769
# 1       1   50    66     W         1     109.530606    453.226059
# 2       1   50    67     W         0     169.576553    821.968480
# 3       1   50    67     W         1     161.036203    814.873517
# 4       1   50    68     W         0     306.549967   1458.003435
# ..    ...  ...   ...   ...       ...            ...           ...
# 411     2   53    83     W         1  103260.474948  14967.496924
# 412     2   53    84  FICA         0  338715.603813  15257.415948
# 413     2   53    84  FICA         1   78103.714190  15427.456590
# 414     2   53    84     W         0  460490.734550  16434.436640
# 415     2   53    84     W         1  128043.928783  16702.700676
#
# [416 rows x 7 columns]

# %%
#vado a sottrarre fra di loro i dati degli eleggibili e non appartenenti alla stessa classe 
TAB2_b= TAB2.groupby(['race',"byr", "year", 'type']).diff(-1)

TAB2_b
# Out:
#      elegible         var_cm     earn_nz
# 0        -1.0       3.802672   20.252710
# 1         NaN            NaN         NaN
# 2        -1.0       8.540349    7.094963
# 3         NaN            NaN         NaN
# 4        -1.0      28.424999   12.337843
# ..        ...            ...         ...
# 411       NaN            NaN         NaN
# 412      -1.0  260611.889623 -170.040642
# 413       NaN            NaN         NaN
# 414      -1.0  332446.805767 -268.264036
# 415       NaN            NaN         NaN
#
# [416 rows x 3 columns]

# %%
#calcolo la radice sulle varianze 
TAB2_b['var_2']= pow(abs(TAB2_b[['var_cm']]), 1/2) 
TAB2_b
# Out:
#      elegible         var_cm     earn_nz       var_2
# 0        -1.0       3.802672   20.252710    1.950044
# 1         NaN            NaN         NaN         NaN
# 2        -1.0       8.540349    7.094963    2.922388
# 3         NaN            NaN         NaN         NaN
# 4        -1.0      28.424999   12.337843    5.331510
# ..        ...            ...         ...         ...
# 411       NaN            NaN         NaN         NaN
# 412      -1.0  260611.889623 -170.040642  510.501606
# 413       NaN            NaN         NaN         NaN
# 414      -1.0  332446.805767 -268.264036  576.582003
# 415       NaN            NaN         NaN         NaN
#
# [416 rows x 4 columns]

# %%
TAB=TAB2[['race','byr', 'year', 'type']]

# %%
TAB
# Out:
#      race  byr  year  type
# 0       1   50    66     W
# 1       1   50    66     W
# 2       1   50    67     W
# 3       1   50    67     W
# 4       1   50    68     W
# ..    ...  ...   ...   ...
# 411     2   53    83     W
# 412     2   53    84  FICA
# 413     2   53    84  FICA
# 414     2   53    84     W
# 415     2   53    84     W
#
# [416 rows x 4 columns]

# %%
tab = pd.concat([TAB, TAB2_b], axis=1)
tab=tab[['race','byr', 'year', 'type','earn_nz', 'var_2' ]]
tab=tab.groupby(['race',"byr", "year", 'type']).sum().reset_index()

# %%
tab
# Out:
#      race  byr  year  type     earn_nz       var_2
# 0       1   50    66     W   20.252710    1.950044
# 1       1   50    67     W    7.094963    2.922388
# 2       1   50    68     W   12.337843    5.331510
# 3       1   50    69     W   -0.479384    9.751349
# 4       1   50    70     W  228.360058   14.768061
# ..    ...  ...   ...   ...         ...         ...
# 203     2   53    82     W -537.136262  481.695201
# 204     2   53    83  FICA -119.008156  486.441265
# 205     2   53    83     W -351.261094  526.664532
# 206     2   53    84  FICA -170.040642  510.501606
# 207     2   53    84     W -268.264036  576.582003
#
# [208 rows x 6 columns]

# %%
#export Excel e immagine 

tab.to_excel('tab1_ex.xlsx', index = False)

# %% [markdown]
# * TAG FICA OBS
# g byte fica= type=="TAXAB"
#
# egen collby= group(white byr year eligible fica)
#
# * SOME CALCULATIONS FOR STANDARD ERRORS
# 	g var= vsd1^2
# 	* VARIANCE OF NONZERO CELLS
# 	g var_nz= (vnu1*(var+vmn1^2)-wt_nz*earn_nz^2)/wt_nz
# 	*  g var_nz= var*(vnu1/wt_nz)	!!!! USE THIS  VERSION TO REPRODUCE SEs IN PUBLISHED TABLE 1 OF ANGRIST (1990) !!!!!
#
# 	* SUM WEIGHTS ACROSS GROUP CELLS
# 	egen sumwt=sum(wt_nz), by(collby)
#
# 	* WEIGHT FOR VARIANCE
# 	g wtmult= 1/(sumwt) /*WOULD USE THIS ONE W/ UNWEIGHTED COLLAPSE SUM STATEMENT -- wt_nz/(sumwt)^2*/
#
# 	* VARIANCE TO SUM
# 	g var_cm= wtmult*var_nz
#
# collapse (mean) var_cm earn_nz white year byr eligible fica [w=wt_nz], by(collby)
# 	g fica2="f" if fica==1
# 		replace fica2="w" if fica==0
#
# drop collby
# egen id= concat(white year eligible fica)
# reshape wide var_cm earn_nz, i(id) j(byr)
#
# drop id
# egen id= concat(white year fica)
# reshape wide var_cm* earn_nz*, i(id) j(eligible)
#
# drop id
# drop fica
#
# egen id= concat(white year)
# reshape wide var_cm* earn_nz*, i(id) j(fica2) string
#
# * GET DIFFERENCES AND STANDARD ERRORS, PUT IN TABLE FORMAT
#
# 	foreach num in 50 51 52 53 {
# 		g c19`num'f= earn_nz`num'1f-earn_nz`num'0f
# 		g se19`num'f=(var_cm`num'1f+var_cm`num'0f)^.5
# 		g c19`num'w= earn_nz`num'1w-earn_nz`num'0w
# 		g se19`num'w=(var_cm`num'1w+var_cm`num'0w)^.5
# 		}
#
# 	keep year white c19* se19*
# 	expand 2
# 	sort year
#
# 	mkmat year c19* se19* if white, matrix(whites1)
# 	mkmat year c19* se19* if white==0, matrix(nonwhites1)
#
# 	mat whites=J(rowsof(whites1),9,0)
# 	mat nonwhites=J(rowsof(nonwhites1),9,0)
#
# 	local top=rowsof(whites1)
# 	local top1=`top'-1
#
# 	foreach mat in whites nonwhites {
# 		mat colnames `mat' = year 1950f 1951f 1952f 1953f 1950w 1951w 1952w 1953w
# 		}
#
# foreach mat in whites nonwhites {
# 	forval val=1(2)`top1' {
# 		mat `mat'[`val',1]=`mat'1[`val',"year"]
# 		mat `mat'[`val',2]=`mat'1[`val',"c1950f"]
# 		mat `mat'[`val',3]=`mat'1[`val',"c1951f"]
# 		mat `mat'[`val',4]=`mat'1[`val',"c1952f"]
# 		mat `mat'[`val',5]=`mat'1[`val',"c1953f"]
# 		mat `mat'[`val',6]=`mat'1[`val',"c1950w"]
# 		mat `mat'[`val',7]=`mat'1[`val',"c1951w"]
# 		mat `mat'[`val',8]=`mat'1[`val',"c1952w"]
# 		mat `mat'[`val',9]=`mat'1[`val',"c1953w"]
# 		}
#
# 	forval val=2(2)`top' {
# 		mat `mat'[`val',1]=.
# 		mat `mat'[`val',2]=`mat'1[`val',"se1950f"]
# 		mat `mat'[`val',3]=`mat'1[`val',"se1951f"]
# 		mat `mat'[`val',4]=`mat'1[`val',"se1952f"]
# 		mat `mat'[`val',5]=`mat'1[`val',"se1953f"]
# 		mat `mat'[`val',6]=`mat'1[`val',"se1950w"]
# 		mat `mat'[`val',7]=`mat'1[`val',"se1951w"]
# 		mat `mat'[`val',8]=`mat'1[`val',"se1952w"]
# 		mat `mat'[`val',9]=`mat'1[`val',"se1953w"]
# 		}
# 		}
#
# * DISPLAY TABLES -- THESE SHOW COEFFS WITH SEs BELOW IN SAME FORMAT AS TABLE 1 IN AER PAPER
# 	mat li whites
# 	mat li nonwhites
#
# log close
